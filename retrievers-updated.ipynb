# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
loader = TextLoader("speech.txt")
docs = loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Artificial Intelligence is transforming healthcare.\nMachine learning helps doctors predict diseases.\nDeep learning improves image recognition.\nFootball is one of the most popular sports.')]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

documents = text_splitter.split_documents(docs)

print(documents)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Artificial Intelligence is transforming healthcare.\nMachine learning helps doctors predict diseases.'), Document(metadata={'source': 'speech.txt'}, page_content='Deep learning improves image recognition.\nFootball is one of the most popular sports.')]

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1713.08it/s]

# %%
vectorstore = FAISS.from_documents(
    documents,
    embeddings
)

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={"k":2}
)

# %%
results = retriever.invoke(
    "How is AI used in healthcare?"
)

# %%
for i, doc in enumerate(results):
    print(f"\nDocument {i+1}")
    print(doc.page_content)
# Out:
# Document 1
# Artificial Intelligence is transforming healthcare.
# Machine learning helps doctors predict diseases.
#
# Document 2
# Deep learning improves image recognition.
# Football is one of the most popular sports.
